# %%
# File for bicycle type Classification Main source is MachineLearningMastery.com

# split into train and test set
g_path = 'D:/Users/Shadow/Documents/GitHub/' #general path for files
# fit a mask rcnn on the kangaroo dataset
from os import listdir
from xml.etree import ElementTree
from numpy import zeros
from numpy import asarray
from mrcnn.utils import Dataset
from mrcnn.config import Config
from mrcnn.model import MaskRCNN
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# %% class that defines and loads the kangaroo dataset
class KangarooDataset(Dataset):
	# load the dataset definitions
	def load_dataset(self, dataset_dir, is_train=True):
		# define one class
		self.add_class("dataset", 1, "kangaroo")
		# define data locations
		images_dir = dataset_dir + '/images/'
		annotations_dir = dataset_dir + '/annots/'
		# find all images
		for filename in listdir(images_dir):
			# extract image id
			image_id = filename[:-4]
			# skip bad images
			if image_id in ['00090']:
				continue
			# skip all images after 150 if we are building the train set
			if is_train and int(image_id) >= 150:
				continue
			# skip all images before 150 if we are building the test/val set
			if not is_train and int(image_id) < 150:
				continue
			img_path = images_dir + filename
			ann_path = annotations_dir + image_id + '.xml'
			# add to dataset
			self.add_image('dataset', image_id=image_id, path=img_path, annotation=ann_path)

	# extract bounding boxes from an annotation file
	def extract_boxes(self, filename):
		# load and parse the file
		tree = ElementTree.parse(filename)
		# get the root of the document
		root = tree.getroot()
		# extract each bounding box
		boxes = list()
		for box in root.findall('.//bndbox'):
			xmin = int(box.find('xmin').text)
			ymin = int(box.find('ymin').text)
			xmax = int(box.find('xmax').text)
			ymax = int(box.find('ymax').text)
			coors = [xmin, ymin, xmax, ymax]
			boxes.append(coors)
		# extract image dimensions
		width = int(root.find('.//size/width').text)
		height = int(root.find('.//size/height').text)
		return boxes, width, height

	# load the masks for an image
	def load_mask(self, image_id):
		# get details of image
		info = self.image_info[image_id]
		# define box file location
		path = info['annotation']
		# load XML
		boxes, w, h = self.extract_boxes(path)
		# create one array for all masks, each on a different channel
		masks = zeros([h, w, len(boxes)], dtype='uint8')
		# create masks
		class_ids = list()
		for i in range(len(boxes)):
			box = boxes[i]
			row_s, row_e = box[1], box[3]
			col_s, col_e = box[0], box[2]
			masks[row_s:row_e, col_s:col_e, i] = 1
			class_ids.append(self.class_names.index('kangaroo'))
		return masks, asarray(class_ids, dtype='int32')

	# load an image reference
	def image_reference(self, image_id):
		info = self.image_info[image_id]
		return info['path']

# define a configuration for the model
class KangarooConfig(Config):
	# define the name of the configuration
	NAME = "kangaroo_cfg"
	# number of classes (background + kangaroo)
	NUM_CLASSES = 1 + 1
	# number of training steps per epoch
	STEPS_PER_EPOCH = 131

# %% prepare train set
train_set = KangarooDataset()
train_set.load_dataset(g_path+'kangaroo', is_train=True)
train_set.prepare()
print('Train: %d' % len(train_set.image_ids))
# prepare test/val set
test_set = KangarooDataset()
test_set.load_dataset(g_path+'kangaroo', is_train=False)
test_set.prepare()
print('Test: %d' % len(test_set.image_ids))
# prepare config
config = KangarooConfig()
config.display()
# define the model
model = MaskRCNN(mode='training', model_dir='./', config=config)
# load weights (mscoco) and exclude the output layers
model.load_weights('mask_rcnn_coco.h5', by_name=True, exclude=["mrcnn_class_logits", "mrcnn_bbox_fc",  "mrcnn_bbox", "mrcnn_mask"])
# train weights (output layers or 'heads')
model.train(train_set, test_set, learning_rate=config.LEARNING_RATE, epochs=5, layers='heads')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-8b0b30746bd2> in <module>
#       8 from numpy import zeros
#       9 from numpy import asarray
# ---> 10 from mrcnn.utils import Dataset
#      11 from mrcnn.config import Config
#      12 from mrcnn.model import MaskRCNN
#
# D:\Users\Shadow\Documents\GitHub\Mask_RCNN\mrcnn\utils.py in <module>
#      14 import random
#      15 import numpy as np
# ---> 16 import tensorflow as tf
#      17 import scipy
#      18 import skimage.color
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# !pip install jupyter
# Out:
# Requirement already satisfied: jupyter in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (1.0.0)
# Requirement already satisfied: nbconvert in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from jupyter) (5.6.1)
# Requirement already satisfied: jupyter-console in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from jupyter) (6.1.0)
# Requirement already satisfied: ipywidgets in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from jupyter) (7.5.1)
# Requirement already satisfied: qtconsole in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from jupyter) (4.7.4)
# Requirement already satisfied: notebook in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from jupyter) (6.0.3)
# Requirement already satisfied: ipykernel in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from jupyter) (5.2.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from nbconvert->jupyter) (0.8.4)
# Requirement already satisfied: pygments in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from nbconvert->jupyter) (2.6.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from nbconvert->jupyter) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from nbconvert->jupyter) (1.4.2)
# Requirement already satisfied: defusedxml in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from nbconvert->jupyter) (0.6.0)
# Requirement already satisfied: bleach in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from nbconvert->jupyter) (3.1.5)
# Requirement already satisfied: testpath in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from nbconvert->jupyter) (0.4.4)
# Requirement already satisfied: jinja2>=2.4 in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from nbconvert->jupyter) (2.11.2)
# Requirement already satisfied: traitlets>=4.2 in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from nbconvert->jupyter) (4.3.3)
# Requirement already satisfied: jupyter-core in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from nbconvert->jupyter) (4.6.3)
# Requirement already satisfied: nbformat>=4.4 in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from nbconvert->jupyter) (5.0.6)
# Requirement already satisfied: ipython in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from jupyter-console->jupyter) (7.14.0)
# Requirement already satisfied: jupyter-client in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from jupyter-console->jupyter) (6.1.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from jupyter-console->jupyter) (3.0.5)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from ipywidgets->jupyter) (3.5.1)
# Requirement already satisfied: pyzmq>=17.1 in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from qtconsole->jupyter) (19.0.1)
# Requirement already satisfied: ipython-genutils in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from qtconsole->jupyter) (0.2.0)
# Requirement already satisfied: qtpy in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from qtconsole->jupyter) (1.9.0)
# Requirement already satisfied: terminado>=0.8.1 in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from notebook->jupyter) (0.8.3)
# Requirement already satisfied: tornado>=5.0 in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from notebook->jupyter) (5.0)
# Requirement already satisfied: prometheus-client in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from notebook->jupyter) (0.7.1)
# Requirement already satisfied: Send2Trash in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from notebook->jupyter) (1.5.0)
# Requirement already satisfied: packaging in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from bleach->nbconvert->jupyter) (20.4)
# Requirement already satisfied: webencodings in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from bleach->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from bleach->nbconvert->jupyter) (1.12.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from jinja2>=2.4->nbconvert->jupyter) (1.1.1)
# Requirement already satisfied: decorator in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from traitlets>=4.2->nbconvert->jupyter) (4.4.2)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from jupyter-core->nbconvert->jupyter) (227)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from nbformat>=4.4->nbconvert->jupyter) (3.2.0)
# Requirement already satisfied: backcall in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from ipython->jupyter-console->jupyter) (0.1.0)
# Requirement already satisfied: pickleshare in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from ipython->jupyter-console->jupyter) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from ipython->jupyter-console->jupyter) (46.1.3)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from ipython->jupyter-console->jupyter) (0.4.3)
# Requirement already satisfied: jedi>=0.10 in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from ipython->jupyter-console->jupyter) (0.17.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from jupyter-client->jupyter-console->jupyter) (2.8.1)
# Requirement already satisfied: wcwidth in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter) (0.1.9)
# Requirement already satisfied: pywinpty>=0.5; os_name == "nt" in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from terminado>=0.8.1->notebook->jupyter) (0.5.7)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from packaging->bleach->nbconvert->jupyter) (2.4.7)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert->jupyter) (19.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert->jupyter) (1.6.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert->jupyter) (0.16.0)
# Requirement already satisfied: parso>=0.7.0 in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from jedi>=0.10->ipython->jupyter-console->jupyter) (0.7.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\shadow\documents\github\mask_rcnn\bikereco\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert->jupyter) (3.1.0)
